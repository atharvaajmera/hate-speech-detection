# %% [markdown]
# # Detailed EDA - Hate Speech Dataset
#
# This notebook performs a detailed exploratory data analysis (EDA) on the raw and cleaned tweet dataset.

# %% [markdown]
# ## 1) Imports and Settings

# %%
from pathlib import Path
from collections import Counter
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import CountVectorizer
sns.set_theme(style="whitegrid")
pd.set_option("display.max_colwidth", 200)
RANDOM_STATE = 42

# %% [markdown]
# ## 2) Load Data

# %%
from pathlib import Path
cwd = Path.cwd().resolve()
candidate_roots = [cwd, cwd.parent]
PROJECT_ROOT = None
for candidate in candidate_roots:
    if (candidate / "data").exists() and (candidate / "requirements.txt").exists():
        PROJECT_ROOT = candidate
        break
if PROJECT_ROOT is None:
    raise FileNotFoundError("Could not resolve project root. Open notebook from the project workspace.")
RAW_PATH = PROJECT_ROOT / "data" / "raw" / "labeled_data.csv"
CLEANED_PATH = PROJECT_ROOT / "data" / "processed" / "cleaned_labeled_data.csv"
if not RAW_PATH.exists():
    raise FileNotFoundError(f"Raw dataset not found at {RAW_PATH}")
df_raw = pd.read_csv(RAW_PATH)
if CLEANED_PATH.exists():
    df_cleaned = pd.read_csv(CLEANED_PATH)
else:
    df_cleaned = None
print("Raw shape:", df_raw.shape)
print("Cleaned available:", df_cleaned is not None)
if df_cleaned is not None:
    print("Cleaned shape:", df_cleaned.shape)
# Out:
# Raw shape: (24783, 7)
# Cleaned available: True
# Cleaned shape: (24783, 8)

# %% [markdown]
# ## 3) Schema and Basic Quality Checks

# %%
display(df_raw.head(5))
print("\nColumns:", list(df_raw.columns))
print("\nDtypes:\n")
print(df_raw.dtypes)

print("\nMissing values:\n")
display(df_raw.isna().sum().to_frame("missing_count"))

duplicate_tweets = df_raw["tweet"].duplicated().sum() if "tweet" in df_raw.columns else 0
print(f"Duplicate tweet rows (by text): {duplicate_tweets}")
# Out:
#    Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0           0      3            0                   0        3      2
# 1           1      3            0                   3        0      1
# 2           2      3            0                   3        0      1
# 3           3      3            0                   2        1      1
# 4           4      6            0                   6        0      1
#
#                                                                                                                                           tweet
# 0  !!! RT @mayasolovely: As a woman you shouldn't complain about cleaning up your house. &amp; as a man you should always take the trash out...
# 1                                                         !!!!! RT @mleew17: boy dats cold...tyga dwn bad for cuffin dat hoe in the 1st place!!
# 2                      !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby4life: You ever fuck a bitch and she start to cry? You be confused as shit
# 3                                                                                !!!!!!!!! RT @C_G_Anderson: @viva_based she look like a tranny
# 4     !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you hear about me might be true or it might be faker than the bitch who told it to ya &#57361;
# Columns: ['Unnamed: 0', 'count', 'hate_speech', 'offensive_language', 'neither', 'class', 'tweet']
#
# Dtypes:
#
# Unnamed: 0             int64
# count                  int64
# hate_speech            int64
# offensive_language     int64
# neither                int64
# class                  int64
# tweet                 object
# dtype: object
#
# Missing values:
#                     missing_count
# Unnamed: 0                      0
# count                           0
# hate_speech                     0
# offensive_language              0
# neither                         0
# class                           0
# tweet                           0
# Duplicate tweet rows (by text): 0

# %% [markdown]
# ## 4) Class Distribution and Imbalance

# %%
label_map = {0: "hate_speech", 1: "offensive_language", 2: "neither"}

if "class" not in df_raw.columns:
    raise KeyError("Expected column 'class' in raw dataset")

class_counts = df_raw["class"].value_counts().sort_index()
class_df = pd.DataFrame({
    "class": class_counts.index,
    "label": class_counts.index.map(lambda x: label_map.get(x, f"class_{x}")),
    "count": class_counts.values,
    "percent": (class_counts.values / len(df_raw) * 100).round(2),
})
display(class_df)

minority_ratio = class_counts.min() / class_counts.max()
print(f"Minority/Majority ratio: {minority_ratio:.4f}")

plt.figure(figsize=(8, 4))
ax = sns.barplot(data=class_df, x="label", y="count", palette="viridis")
ax.set_title("Class Distribution")
ax.set_xlabel("Class")
ax.set_ylabel("Count")
for i, v in enumerate(class_df["count"]):
    ax.text(i, v, str(v), ha="center", va="bottom", fontsize=9)
plt.xticks(rotation=15)
plt.tight_layout()
plt.show()
# Out:
#    class               label  count  percent
# 0      0         hate_speech   1430     5.77
# 1      1  offensive_language  19190    77.43
# 2      2             neither   4163    16.80
# Minority/Majority ratio: 0.0745
# C:\Users\Atharva\AppData\Local\Temp\ipykernel_16268\3446676554.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=class_df, x="label", y="count", palette="viridis")

# %% [markdown]
# ## 5) Tweet Length Analysis

# %%
df_len = df_raw.copy()
df_len["tweet"] = df_len["tweet"].astype(str)
df_len["char_len"] = df_len["tweet"].str.len()
df_len["word_len"] = df_len["tweet"].str.split().str.len()

display(df_len[["char_len", "word_len"]].describe(percentiles=[0.1, 0.25, 0.5, 0.75, 0.9, 0.99]))

fig, axes = plt.subplots(1, 2, figsize=(13, 4))
sns.histplot(df_len["char_len"], bins=50, kde=True, ax=axes[0], color="steelblue")
axes[0].set_title("Distribution of Tweet Character Length")
axes[0].set_xlabel("Characters")

sns.histplot(df_len["word_len"], bins=40, kde=True, ax=axes[1], color="darkorange")
axes[1].set_title("Distribution of Tweet Word Length")
axes[1].set_xlabel("Words")
plt.tight_layout()
plt.show()
# Out:
#            char_len      word_len
# count  24783.000000  24783.000000
# mean      85.436065     14.117016
# std       41.548238      6.825525
# min        5.000000      1.000000
# 10%       34.000000      6.000000
# 25%       52.000000      9.000000
# 50%       81.000000     13.000000
# 75%      119.000000     19.000000
# 90%      140.000000     24.000000
# 99%      174.000000     29.000000
# max      754.000000     52.000000

# %%
fig, axes = plt.subplots(1, 2, figsize=(13, 4))
sns.boxplot(data=df_len, x="class", y="char_len", ax=axes[0], palette="Set2")
axes[0].set_title("Character Length by Class")
axes[0].set_xlabel("Class")

sns.boxplot(data=df_len, x="class", y="word_len", ax=axes[1], palette="Set3")
axes[1].set_title("Word Length by Class")
axes[1].set_xlabel("Class")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Atharva\AppData\Local\Temp\ipykernel_16268\991115334.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_len, x="class", y="char_len", ax=axes[0], palette="Set2")
# C:\Users\Atharva\AppData\Local\Temp\ipykernel_16268\991115334.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_len, x="class", y="word_len", ax=axes[1], palette="Set3")

# %% [markdown]
# ## 6) Pattern Counts in Raw Tweets

# %%
URL_RE = re.compile(r"https?://\\S+|www\\.\\S+", re.IGNORECASE)
MENTION_RE = re.compile(r"@\\w+")
HASHTAG_RE = re.compile(r"#\\w+")
RT_RE = re.compile(r"\\bRT\\b", re.IGNORECASE)

df_pat = df_raw.copy()
df_pat["tweet"] = df_pat["tweet"].astype(str)
df_pat["has_url"] = df_pat["tweet"].str.contains(URL_RE)
df_pat["has_mention"] = df_pat["tweet"].str.contains(MENTION_RE)
df_pat["has_hashtag"] = df_pat["tweet"].str.contains(HASHTAG_RE)
df_pat["has_rt"] = df_pat["tweet"].str.contains(RT_RE)

pattern_summary = pd.DataFrame({
    "feature": ["has_url", "has_mention", "has_hashtag", "has_rt"],
    "count": [
        int(df_pat["has_url"].sum()),
        int(df_pat["has_mention"].sum()),
        int(df_pat["has_hashtag"].sum()),
        int(df_pat["has_rt"].sum()),
    ],
})
pattern_summary["percent"] = (pattern_summary["count"] / len(df_pat) * 100).round(2)
display(pattern_summary)

plt.figure(figsize=(8, 4))
ax = sns.barplot(data=pattern_summary, x="feature", y="percent", palette="magma")
ax.set_title("Tweet Patterns in Raw Data")
ax.set_ylabel("Percent of tweets")
ax.set_xlabel("")
plt.tight_layout()
plt.show()
# Out:
#        feature  count  percent
# 0      has_url      0      0.0
# 1  has_mention      0      0.0
# 2  has_hashtag      0      0.0
# 3       has_rt      0      0.0
# C:\Users\Atharva\AppData\Local\Temp\ipykernel_16268\2888679025.py:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=pattern_summary, x="feature", y="percent", palette="magma")

# %% [markdown]
# ## 7) Frequent Tokens and N-grams (Raw vs Cleaned)

# %%
def top_ngrams(corpus, ngram_range=(1, 1), top_k=20, min_df=2):
    vec = CountVectorizer(stop_words="english", ngram_range=ngram_range, min_df=min_df)
    x = vec.fit_transform(corpus)
    counts = np.asarray(x.sum(axis=0)).ravel()
    terms = np.array(vec.get_feature_names_out())
    idx = counts.argsort()[::-1][:top_k]
    return pd.DataFrame({"term": terms[idx], "count": counts[idx]})

raw_text = df_raw["tweet"].astype(str)
raw_unigrams = top_ngrams(raw_text, ngram_range=(1, 1), top_k=20)
raw_bigrams = top_ngrams(raw_text, ngram_range=(2, 2), top_k=20)

display(raw_unigrams)
display(raw_bigrams.head(10))
# Out:
#        term  count
# 0     bitch   8348
# 1        rt   7647
# 2    128514   3241
# 3   bitches   3119
# 4      http   2915
# 5      like   2787
# 6      hoes   2403
# 7     pussy   2160
# 8       hoe   1951
# 9      8220   1726
# 10     8221   1682
# 11      ass   1579
# 12      don   1509
# 13     just   1471
# 14     fuck   1428
# 15      got   1290
# 16     shit   1287
# 17     8230   1265
# 18    nigga   1229
# 19    trash   1158
#             term  count
# 0  128514 128514   1720
# 1  128557 128557    255
# 2      bitch ass    242
# 3     like bitch    223
# 4      look like    202
# 5       yo bitch    194
# 6      ass bitch    193
# 7      bad bitch    184
# 8      http 8230    151
# 9  128514 128557    150

# %%
if df_cleaned is not None and "clean_tweet" in df_cleaned.columns:
    clean_text = df_cleaned["clean_tweet"].fillna("").astype(str)
    clean_unigrams = top_ngrams(clean_text, ngram_range=(1, 1), top_k=20)
    clean_bigrams = top_ngrams(clean_text, ngram_range=(2, 2), top_k=20)
    display(clean_unigrams)
    display(clean_bigrams.head(10))
else:
    print("Cleaned dataset/column not available. Run preprocess_data.py first.")
# Out:
#        term  count
# 0     bitch   8343
# 1   bitches   3118
# 2      like   2787
# 3      hoes   2396
# 4     pussy   2160
# 5       hoe   1951
# 6       ass   1579
# 7       don   1509
# 8      just   1471
# 9      fuck   1428
# 10      got   1291
# 11     shit   1287
# 12    nigga   1229
# 13    trash   1158
# 14      lol   1107
# 15      amp    930
# 16      ain    925
# 17     know    811
# 18   niggas    790
# 19     love    705
#           term  count
# 0    bitch ass    243
# 1   like bitch    224
# 2    look like    202
# 3    ass bitch    195
# 4     yo bitch    194
# 5    bad bitch    184
# 6  bad bitches    149
# 7   fuck bitch    139
# 8        gt gt    138
# 9    ass nigga    133

# %% [markdown]
# ## 8) Class-wise Top Terms (Cleaned Text Preferred)

# %%
source_df = df_cleaned if (df_cleaned is not None and "clean_tweet" in df_cleaned.columns) else df_raw.copy()
text_col = "clean_tweet" if "clean_tweet" in source_df.columns else "tweet"
source_df[text_col] = source_df[text_col].fillna("").astype(str)

for cls in sorted(source_df["class"].unique()):
    subset = source_df[source_df["class"] == cls][text_col]
    top_terms = top_ngrams(subset, ngram_range=(1, 1), top_k=15, min_df=2)
    print(f"\nClass {cls} ({label_map.get(cls, f'class_{cls}')}) - top terms")
    display(top_terms)
# Out:
# Class 0 (hate_speech) - top terms
#        term  count
# 0     bitch    209
# 1    faggot    191
# 2      like    169
# 3     nigga    140
# 4       ass    138
# 5     white    127
# 6      fuck    121
# 7     trash    113
# 8    nigger    112
# 9   fucking     95
# 10      don     77
# 11   niggas     76
# 12      fag     76
# 13     just     75
# 14  faggots     62
# Class 1 (offensive_language) - top terms
#        term  count
# 0     bitch   8124
# 1   bitches   3059
# 2      hoes   2329
# 3      like   2313
# 4     pussy   2104
# 5       hoe   1872
# 6       ass   1439
# 7      fuck   1307
# 8       don   1278
# 9      shit   1222
# 10      got   1141
# 11     just   1140
# 12    nigga   1089
# 13      lol    912
# 14      ain    872
# Class 2 (neither) - top terms
#        term  count
# 0     trash    691
# 1      like    305
# 2      bird    304
# 3   charlie    261
# 4      just    256
# 5   yankees    225
# 6    yellow    219
# 7       amp    177
# 8     birds    173
# 9       don    154
# 10      lol    146
# 11  colored    117
# 12   monkey    115
# 13   ghetto    113
# 14      got    102

# %% [markdown]
# ## 9) Short Error-Prone or Extreme Samples

# %%
tmp = df_raw.copy()
tmp["tweet"] = tmp["tweet"].astype(str)
tmp["word_len"] = tmp["tweet"].str.split().str.len()

print("Very short tweets (<= 3 words):")
display(tmp[tmp["word_len"] <= 3][["class", "tweet"]].head(15))

print("Very long tweets (top 1% by word length):")
threshold = tmp["word_len"].quantile(0.99)
display(tmp[tmp["word_len"] >= threshold][["class", "tweet", "word_len"]].head(15))
# Out:
# Very short tweets (<= 3 words):
#       class                                       tweet
# 647       0        "poor whitey" http://t.co/3UkKeyznz8
# 667       1   #AsAGiraffes pussy http://t.co/YaaTsF52tu
# 721       1             #IDontHaveTimeFor Ratchet hoes.
# 741       2                        #NP "Centuries" ~FOB
# 804       2                                    #Yankees
# 827       1                               #boom bitches
# 837       1                          #honeybadger bitch
# 845       2                       #metal only, honkies!
# 923       1        #vegas #bitch http://t.co/wbAqQ5vFpd
# 924       1                    #wallofthewasatch bitch!
# 950       2      &#128075; hi-ho http://t.co/FiC4FnRutZ
# 1028      1                              &#128553; cunt
# 1029      2                        &#128553; monkey mad
# 1798      1  &#8220;@itsdaniellef: &#128521;&#8221; hoe
# 2206      2                            1-800-slap-a-hoe
# Very long tweets (top 1% by word length):
#       class  \
# 423       1
# 526       0
# 638       1
# 643       1
# 813       2
# 931       1
# 960       1
# 961       1
# 969       0
# 1064      1
# 1397      1
# 1618      1
# 1688      1
# 1926      1
# 1995      1
#
#                                                                                                                                                                                                         tweet  \
# 423                                                                     "Baby I like being on your left side" no bitch you can't be there Cuz the street on that side and Twitter said I ain't real if you do
# 526                                                              "My grandma used to call me a porch monkey all the time... Come to think of it she did refer to a broken bottle as a nigger knife" &#128563;
# 638                                                              "if i wasnt in a work place id deck you" aye fucking right, I'd give you a tyson 4 combo nd end you with an uppercut. Shut the fuck up bitch
# 643                                                                  "no pussy, or not tryna go to the studio, don't CALL my mufuckin crib like that, god. Yo. Word up god I will BUSS YO SHIT, god, word up"
# 813                                                               #Yankees I went to Golds with Cruz in 2010 when he was a Sound. No upper /lower body strength.. Hmm now 40 HR hitter. Won't say the S word.
# 931                                                               $3 bud Lites and $4 well shots at the bar tn, plus I'm giving away a trip to Las Vegas. So if you're not a cunt come visit me at Bourbon St
# 960                              &#128139;&#128175; - ugh bitch I love you &amp; that A S S &#128553; your just simply FLAWLESS &#128149; I remember when you cute a peice of your hair hella short &#128514;
# 961             &#128149;&#128149;&#128149; pussy ride dick like she a Jamaican / \ / &#128167;\ \n. */. &#127796; |. &#165;~ ! &#127796;. | &gt; \ \n&#128043; $. / &#127806;\ ; &#128043; ) &amp;&#128043;*
# 969                                           &#128514; RT @TheOnlyReed: LMFAO RT @Tone314: If you watching porn &amp; beating off &amp; yo homie text u &amp; it show his name in the banner you're a faggot
# 1064                                             &#128588;RT @Nay_btw It amazes me how niggas can fuck w/ EVERY bitch but when a nigga try to talk to his bitch he wanna cry about it&#128533; I need answers
# 1397                                           &#8220;@M_Rad: You was with the bitch with the fat ass &#128514;&#8221;only way to live when u young that shit gonna get old tho and have a lot of dents in it
# 1618                                    &#8220;@YeridZee: I'm not a bitch like @Vikyfdez15 &#128129; lol&#8221; sorry not sorry, tried to give him a hint that I didn't want to speak to him so idc &#128524;
# 1688  &#8220;@_yeaimmaBOSS: &#8220;@100046729: I wonder if I @ oomf I be like I want fuck would I be wrong or &#128533;&#8221; you a be one brave as bitch&#128514;&#128514;&#8221;one day &#128553;&#1285...
# 1926                             &#8220;@thekiddfranky: I talk to any girl who paid over 300$ for her sew in, show me u Atleast got some type of boss bitch in you lol&#8221; wth &#128557;&#128557;&#128557;
# 1995                                               &amp; I MOST DEFIANTLY WILL NOT let no bitch who FW a nigga I ALREADY HAD get the best out of me &#128514;&#128557; Fuccin wit my Hand-Me-Downs &amp; shit
#
#       word_len
# 423         29
# 526         29
# 638         31
# 643         29
# 813         29
# 931         32
# 960         31
# 961         30
# 969         29
# 1064        30
# 1397        31
# 1618        29
# 1688        29
# 1926        29
# 1995        29

# %% [markdown]
# ## 10) Summary Notes Template
#
# ### Filled Summary (Current Dataset)
#
# - Class imbalance severity: Strong imbalance is present. Class counts are `0: 1430` (5.77%), `1: 19190` (77.43%), `2: 4163` (16.80%). Minority/majority ratio is ~`0.0745`.
# - Evidence of noisy patterns: Raw tweets contain high social-media noise: mentions in `57.25%` of rows, hashtags in `30.80%`, retweet token `RT` in `28.89%`, URLs in `12.04%`.
# - Length characteristics: Average tweet length is about `14.12` words; 99th percentile is around `29` words. The dataset includes very short texts and long-tail tweets that may be harder to classify consistently.
# - Most informative terms/n-grams per class: Class-wise frequent-token sections show overlap between class `0` and class `1`, which explains confusion between hate speech and offensive language in model results.
# - Suggested modeling actions:
#   1. Keep class-aware training (`class_weight='balanced'` or custom weights).
#   2. Prioritize `f1_macro` and class-0 metrics (not accuracy alone).
#   3. Use threshold tuning / decision calibration for class `0` to improve hate-speech recall-precision tradeoff.
#   4. Add richer text features (word + char n-grams) and compare with tuned LinearSVC.
#   5. Continue cleaning social artifacts and inspect frequent false positives/false negatives for label-boundary ambiguity.
